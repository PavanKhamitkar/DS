# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("https://raw.githubusercontent.com/Ahmad-Almosallam/Students-Academic-Performance-Classification/main/edu-data.csv")
df
# Out:
#     gender NationalITy PlaceofBirth       StageID GradeID SectionID  \
# 0        M          KW       KuwaIT    lowerlevel    G-04         A
# 1        M          KW       KuwaIT    lowerlevel    G-04         A
# 2        M          KW       KuwaIT    lowerlevel    G-04         A
# 3        M          KW       KuwaIT    lowerlevel    G-04         A
# 4        M          KW       KuwaIT    lowerlevel    G-04         A
# ..     ...         ...          ...           ...     ...       ...
# 475      F      Jordan       Jordan  MiddleSchool    G-08         A
# 476      F      Jordan       Jordan  MiddleSchool    G-08         A
# 477      F      Jordan       Jordan  MiddleSchool    G-08         A
# 478      F      Jordan       Jordan  MiddleSchool    G-08         A
# 479      F      Jordan       Jordan  MiddleSchool    G-08         A
#
#          Topic Semester Relation  raisedhands  VisITedResources  \
# 0           IT        F   Father           15                16
# ...

# %%
df.isnull().sum()
# Out:
# gender                      0
# NationalITy                 0
# PlaceofBirth                0
# StageID                     0
# GradeID                     0
# SectionID                   0
# Topic                       0
# Semester                    0
# Relation                    0
# raisedhands                 0
# VisITedResources            0
# AnnouncementsView           0
# Discussion                  0
# ParentAnsweringSurvey       0
# ParentschoolSatisfaction    0
# StudentAbsenceDays          0
# Class                       0
# dtype: int64

# %%
import matplotlib.pyplot as plt

# %%
fig , x = plt.subplots(figsize=(6,4))
ax = plt.hist(df['Semester'], color='b', edgecolor='b')
plt.title('Graph')
plt.show()

# %%
df[df['Semester'].str.contains('T') == False]
df
# Out:
#     gender NationalITy PlaceofBirth       StageID GradeID SectionID  \
# 0        M          KW       KuwaIT    lowerlevel    G-04         A
# 1        M          KW       KuwaIT    lowerlevel    G-04         A
# 2        M          KW       KuwaIT    lowerlevel    G-04         A
# 3        M          KW       KuwaIT    lowerlevel    G-04         A
# 4        M          KW       KuwaIT    lowerlevel    G-04         A
# ..     ...         ...          ...           ...     ...       ...
# 475      F      Jordan       Jordan  MiddleSchool    G-08         A
# 476      F      Jordan       Jordan  MiddleSchool    G-08         A
# 477      F      Jordan       Jordan  MiddleSchool    G-08         A
# 478      F      Jordan       Jordan  MiddleSchool    G-08         A
# 479      F      Jordan       Jordan  MiddleSchool    G-08         A
#
#          Topic Semester Relation  raisedhands  VisITedResources  \
# 0           IT        F   Father           15                16
# ...

# %%
df['gender'].value_counts()
# Out:
# gender
# M    305
# F    175
# Name: count, dtype: int64

# %%
df.head(3)
# Out:
#   gender NationalITy PlaceofBirth     StageID GradeID SectionID Topic  \
# 0      M          KW       KuwaIT  lowerlevel    G-04         A    IT
# 1      M          KW       KuwaIT  lowerlevel    G-04         A    IT
# 2      M          KW       KuwaIT  lowerlevel    G-04         A    IT
#
#   Semester Relation  raisedhands  VisITedResources  AnnouncementsView  \
# 0        F   Father           15                16                  2
# 1        F   Father           20                20                  3
# 2        F   Father           10                 7                  0
#
#    Discussion ParentAnsweringSurvey ParentschoolSatisfaction  \
# 0          20                   Yes                     Good
# 1          25                   Yes                     Good
# 2          30                    No                      Bad
#
#   StudentAbsenceDays Class
# 0            Under-7     M
# 1            Under-7     M
# 2            Above-7     L

# %%
df['raisedhands'] = df['raisedhands']/df['raisedhands'].max()
df['VisITedResources'] = df['VisITedResources']/df['VisITedResources'].max()

# %%
df[['raisedhands','VisITedResources']].head(10)
# Out:
#    raisedhands  VisITedResources
# 0         0.15          0.161616
# 1         0.20          0.202020
# 2         0.10          0.070707
# 3         0.30          0.252525
# 4         0.40          0.505051
# 5         0.42          0.303030
# 6         0.35          0.121212
# 7         0.50          0.101010
# 8         0.12          0.212121
# 9         0.70          0.808081

# %%
df['GradeID'].value_counts()
# Out:
# GradeID
# G-02    147
# G-08    116
# G-07    101
# G-04     48
# G-06     32
# G-11     13
# G-12     11
# G-09      5
# G-10      4
# G-05      3
# Name: count, dtype: int64

# %%
df['GradeID'].replace({"G-01":1,"G-02":2,"G-03":3,"G-04":4,"G-05":5,"G-06":6,"G-07":7,"G-08":8,"G-09":9,"G-10":10,"G-11":11,"G-12":12}, inplace=True)
df['GradeID']
# Out:
# C:\Users\khami\AppData\Local\Temp\ipykernel_2904\4045909062.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['GradeID'].replace({"G-01":1,"G-02":2,"G-03":3,"G-04":4,"G-05":5,"G-06":6,"G-07":7,"G-08":8,"G-09":9,"G-10":10,"G-11":11,"G-12":12}, inplace=True)
# ...

# %%
df['StudentAbsenceDays'].replace({'Under-7':0, 'Above-7':1}, inplace=True)
df['StudentAbsenceDays'].value_counts()
# Out:
# C:\Users\khami\AppData\Local\Temp\ipykernel_2904\3734313920.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['StudentAbsenceDays'].replace({'Under-7':0, 'Above-7':1}, inplace=True)
# ...

# %%
df['StudentAbsenceDays']
# Out:
# 0      0
# 1      0
# 2      1
# 3      1
# 4      1
#       ..
# 475    1
# 476    0
# 477    0
# 478    1
# 479    1
# Name: StudentAbsenceDays, Length: 480, dtype: int64

# %%
df['Discussion'].value_counts()
# Out:
# Discussion
# 70    24
# 40    23
# 33    21
# 50    18
# 30    17
#       ..
# 95     1
# 65     1
# 76     1
# 73     1
# 62     1
# Name: count, Length: 90, dtype: int64

# %%
minVal = df['Discussion'].min()
maxVal = df['Discussion'].max()
print(minVal,maxVal)
# Out:
# 1 99

# %%
bins = np.linspace(minVal,maxVal,4)
bins
# Out:
# array([ 1.        , 33.66666667, 66.33333333, 99.        ])

# %%
labels = ['small','medium','big']

# %%
df['bins'] = pd.cut(df['Discussion'], bins=bins,labels=labels,include_lowest=True)

# %%
df['bins'].value_counts()
# Out:
# bins
# small     221
# medium    130
# big       129
# Name: count, dtype: int64

# %%
df
# Out:
#     gender NationalITy PlaceofBirth       StageID  GradeID SectionID  \
# 0        M          KW       KuwaIT    lowerlevel        4         A
# 1        M          KW       KuwaIT    lowerlevel        4         A
# 2        M          KW       KuwaIT    lowerlevel        4         A
# 3        M          KW       KuwaIT    lowerlevel        4         A
# 4        M          KW       KuwaIT    lowerlevel        4         A
# ..     ...         ...          ...           ...      ...       ...
# 475      F      Jordan       Jordan  MiddleSchool        8         A
# 476      F      Jordan       Jordan  MiddleSchool        8         A
# 477      F      Jordan       Jordan  MiddleSchool        8         A
# 478      F      Jordan       Jordan  MiddleSchool        8         A
# 479      F      Jordan       Jordan  MiddleSchool        8         A
#
#          Topic Semester Relation  raisedhands  VisITedResources  \
# 0           IT        F   Father         0.15          0.161616
# ...
